-- %% [markdown]
-- ## Extra point
-- ### Output to json

-- %%
with cte as(
        with t1 as(    
            SELECT b.name "artist_name", artistid, c.name "song_name", sum(stream) "stream", no_followers "followers"
                from song_artist a
            inner join artist b on a.artist_artistid = b.artistid
            inner join song c on a.song_songid = c.songid
                GROUP BY b.name, artistid, c.name
                ORDER BY stream DESC
        ),t2 as(
        SELECT  artistid, artist_name, song_name, stream, followers,
                rank() over w as rank
            from t1 
            GROUP BY artist_name, artistid, song_name, stream, followers
            window w as (PARTITION by artistid, artist_name ORDER BY artistid, artist_name, stream desc)
        )

        SELECT  artistid, artist_name, song_name,
                to_char(stream, '999G999G999') "total_stream",
                to_char(followers, '999G999G999') "no_followers"
                
        from t2 
            where rank=1
    )

SELECT json_agg(cte) from cte
-- Out:
-- (1 row(s) affected)
-- Total execution time: 00:00:00.023
-- <table><tr><th>json_agg</th></tr><tr><td>[{&quot;artistid&quot;: &quot;187E &quot;, &quot;artist_name&quot;: &quot;187 Strassenbande&quot;, &quot;song_name&quot;: &quot;Extasy&quot;, &quot;total_stream&quot;: &quot;   5,203,700&quot;, &quot;no_followers&quot;: &quot;  22,834,346&quot;}, {&quot;artistid&quot;: &quot;21SV &quot;, &quot;artist_name&quot;: &quot;21 Savage&quot;, &quot;song_name&quot;: &quot;Rich Nigga Shit (feat. Young Thug)&quot;, &quot;total_stream&quot;: &quot;   9,129,562&quot;, &quot;no_followers&quot;: &quot;   5,287,203&quot;}, {&quot;artistid&quot;: &quot;24KN &quot;, &quot;artist_name&quot;: &quot;24kGoldn&quot;, &quot;song_name&quot;: &quot;Mood (feat. iann dior)&quot;, &quot;total_stream&quot;: &quot;  10,222,056&quot;, &quot;no_followers&quot;: &quot;  20,446,545&quot;}, {&quot;artistid&quot;: &quot;347N &quot;, &quot;artist_name&quot;: &quot;347aidan&quot;, &quot;song_name&quot;: &quot;Dancing in My Room&quot;, &quot;total_stream&quot;: &quot;   4,914,093&quot;, &quot;no_followers&quot;: &quot;   9,577,677&quot;}, {&quot;artistid&quot;: &quot;5SOS &quot;, &quot;artist_name&quot;: &quot;5 Seconds of Summer&quot;, &quot;song_name&quot;: &quot;No Shame&quot;, &quot;total_stream&quot;: &quot;   5,835,260&quot;, &quot;no_followers&quot;: &quot;   1,682,777&quot;}, {&quot;artistid&quot;: &quot;6IXE &quot;, &quot;artist_name&quot;: &quot;6ix9ine&quot;, &quot;song_name&quot;: &quot;YAYA&quot;, &quot;total_stream&quot;: &quot;   4,729,070&quot;, &quot;no_followers&quot;: &quot;      52,786&quot;}, {&quot;artistid&quot;: &quot;6LAK &quot;, &quot;artist_name&quot;: &quot;6LACK&quot;, &quot;song_name&quot;: &quot;Calling My Phone&quot;, &quot;total_stream&quot;: &quot;   5,467,753&quot;, &quot;no_followers&quot;: &quot;  13,266,585&quot;}, {&quot;artistid&quot;: &quot;A7SS &quot;, &quot;artist_name&quot;: &quot;A7S&quot;, &quot;song_name&quot;: &quot;Your Love (9PM)&quot;, &quot;total_stream&quot;: &quot;   8,935,418&quot;, &quot;no_followers&quot;: &quot;  12,317,148&quot;}, {&quot;artistid&quot;: &quot;AAKT &quot;, &quot;artist_name&quot;: &quot;AK AUSSERKONTROLLE&quot;, &quot;song_name&quot;: &quot;In meinem Benz&quot;, &quot;total_stream&quot;: &quot;   5,494,500&quot;, &quot;no_followers&quot;: &quot;  18,972,610&quot;}, {&quot;artistid&quot;: &quot;ABRA &quot;, &quot;artist_name&quot;: &quot;ABRA&quot;, &quot;song_name&quot;: &quot;SORRY PAPI&quot;, &quot;total_stream&quot;: &quot;  11,066,606&quot;, &quot;no_followers&quot;: &quot;      37,225&quot;}, {&quot;artistid&quot;: &quot;ABWH &quot;, &quot;artist_name&quot;: &quot;A Boogie Wit da Hoodie&quot;, &quot;song_name&quot;: &quot;King Of My City&quot;, &quot;total_stream&quot;: &quot;   5,922,748&quot;, &quot;no_followers&quot;: &quot;   9,844,321&quot;}, {&quot;artistid&quot;: &quot;ACHO &quot;, &quot;artist_name&quot;: &quot;Achille Lauro&quot;, &quot;song_name&quot;: &quot;MILLE (feat. Orietta Berti)&quot;, &quot;total_stream&quot;: &quot;   5,341,887&quot;, &quot;no_followers&quot;: &quot;      68,561&quot;}, {&quot;artistid&quot;: &quot;ADRA &quot;, &quot;artist_name&quot;: &quot;Adriana Proenza&quot;, &quot;song_name&quot;: &quot;Can We Kiss Forever?&quot;, &quot;total_stream&quot;: &quot;   4,397,385&quot;, &quot;no_followers&quot;: &quot;   4,867,789&quot;}, {&quot;artistid&quot;: &quot;ALAR &quot;, &quot;artist_name&quot;: &quot;Alan Walker&quot;, &quot;song_name&quot;: &quot;Alone, Pt. II&quot;, &quot;total_stream&quot;: &quot;   4,395,061&quot;, &quot;no_followers&quot;: &quot;  18,768,894&quot;}, {&quot;artistid&quot;: &quot;ALEE &quot;, &quot;artist_name&quot;: &quot;Alex Rose&quot;, &quot;song_name&quot;: &quot;Me Fije&quot;, &quot;total_stream&quot;: &quot;   5,068,677&quot;, &quot;no_followers&quot;: &quot;   2,915,751&quot;}, {&quot;artistid&quot;: &quot;ALEO &quot;, &quot;artist_name&quot;: &quot;Alessandra Amoroso&quot;, &quot;song_name&quot;: &quot;Karaoke&quot;, &quot;total_stream&quot;: &quot;   4,374,448&quot;, &quot;no_followers&qu ...

-- %%
with cte as(
        with yau as 
            (SELECT *, "ad" + "premium" "total" from 
                (SELECT year, a.yearly_active_users "ad"
                from revenue_ad_supported a) a1
                inner join 
                (select year, b.yearly_active_users "premium" 
                from revenue_premium b ) b1
                USING (year) )
        SELECT year, to_char(ad,'999G999G999') "yearly active user ad", to_char(premium,'999G999G999') "yearly active user premium", 
        to_char((total / 365), '999G999') "user per day"
        from yau
    )

SELECT json_agg(cte) from cte
-- Out:
-- (1 row(s) affected)
-- Total execution time: 00:00:00.014
-- <table><tr><th>json_agg</th></tr><tr><td>[{&quot;year&quot;: &quot;2015&quot;, &quot;yearly active user ad&quot;: &quot;  63,000,000&quot;, &quot;yearly active user premium&quot;: &quot;  28,000,000&quot;, &quot;user per day&quot;: &quot; 249,315&quot;}, {&quot;year&quot;: &quot;2016&quot;, &quot;yearly active user ad&quot;: &quot;  75,000,000&quot;, &quot;yearly active user premium&quot;: &quot;  48,000,000&quot;, &quot;user per day&quot;: &quot; 336,986&quot;}, {&quot;year&quot;: &quot;2017&quot;, &quot;yearly active user ad&quot;: &quot;  89,000,000&quot;, &quot;yearly active user premium&quot;: &quot;  71,000,000&quot;, &quot;user per day&quot;: &quot; 438,356&quot;}, {&quot;year&quot;: &quot;2018&quot;, &quot;yearly active user ad&quot;: &quot; 111,000,000&quot;, &quot;yearly active user premium&quot;: &quot;  96,000,000&quot;, &quot;user per day&quot;: &quot; 567,123&quot;}, {&quot;year&quot;: &quot;2019&quot;, &quot;yearly active user ad&quot;: &quot; 147,000,000&quot;, &quot;yearly active user premium&quot;: &quot; 124,000,000&quot;, &quot;user per day&quot;: &quot; 742,466&quot;}, {&quot;year&quot;: &quot;2020&quot;, &quot;yearly active user ad&quot;: &quot; 190,000,000&quot;, &quot;yearly active user premium&quot;: &quot; 155,000,000&quot;, &quot;user per day&quot;: &quot; 945,205&quot;}]</td></tr></table>
